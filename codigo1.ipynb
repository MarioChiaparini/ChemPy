# %%
import pandas as pd
import numpy as np
import scipy

# %%
#load data
data = pd.read_excel("./Dados/raman spectra.xlsx")
data.head()
# Out:
#    Unnamed: 0  Raman Shift (cm-1)     Intensity
# 0         NaN             1285312  0.000000e+00
# 1         NaN             1290133  4.804080e-01
# 2         NaN             1294954  7.531700e+05
# 3         NaN             1299775  7.913200e+05
# 4         NaN             1304596  1.948792e+06

# %%
df = pd.DataFrame(data)
df = df.drop(["Unnamed: 0"],axis=1)
df.head()
# Out:
#    Raman Shift (cm-1)     Intensity
# 0             1285312  0.000000e+00
# 1             1290133  4.804080e-01
# 2             1294954  7.531700e+05
# 3             1299775  7.913200e+05
# 4             1304596  1.948792e+06

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = df["Raman Shift (cm-1)"]
y = df["Intensity"]
plt.figure(figsize=(95,10))
plt.plot(x,y)
