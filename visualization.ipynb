# %%
import pandas as pd
import numpy as np
import scipy
#https://rruff.info/
#site captação de dados de minerais

# %%
#load data
quart = pd.read_excel('./Dados/raman.xlsx', sheet_name='quartzo') #quartzo 45 ccw 
gold = pd.read_excel('./Dados/raman.xlsx', sheet_name='gold') #gold 785 nm
kh2po4 = pd.read_excel('./Dados/raman.xlsx', sheet_name='KH2PO4')#KH2PO4 (Potassium Dihydrogen Phosphate R120165) 780 nm
iron = pd.read_excel('./Dados/raman.xlsx', sheet_name='iron')#Iron 785 nm
diamond = pd.read_excel('./Dados/raman.xlsx', sheet_name='diamante')#diamante 45 ccw

# %%
iron.head()
# Out:
#    Raman Shift (cm-1)  Intensity
# 0            164.8920   0.000000
# 1            165.3741   5.093353
# 2            165.8563  17.744720
# 3            166.3384  14.198180
# 4            166.8205   0.241394

# %%
diamond.head()
# Out:
#    Raman Shift (cm-1)  Intensity
# 0             114.440   0.000000
# 1             115.671  18.810240
# 2             116.903   0.450562
# 3             118.134  21.138120
# 4             119.365  46.354610

# %%
quart.head()
# Out:
#    Raman Shift (cm-1)  Intensity
# 0              47.490      0.000
# 1              48.899      4.203
# 2              50.308     39.490
# 3              51.717    107.876
# 4              53.126    150.753

# %%
gold.head()
# Out:
#    Raman Shift (cm-1)  Intensity
# 0            274.8146   7995.232
# 1            275.2968   7989.121
# 2            275.7789   8000.014
# 3            276.2610   8022.771
# 4            276.7431   8036.049

# %%
kh2po4.head()
# Out:
#    Raman Shift (cm-1)  Intensity
# 0            102.7704   0.000000
# 1            103.2525   0.018066
# 2            103.7346   0.222046
# 3            104.2167   0.718872
# 4            104.6988   2.115967

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
x = quart["Raman Shift (cm-1)"]
y = quart["Intensity"]
plt.figure(figsize=(25,10))
plt.plot(x,y)
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.show()

# %%
x = gold["Raman Shift (cm-1)"]
y = gold["Intensity"]
plt.figure(figsize=(25,10))
plt.plot(x,y)
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.xlim()
plt.show()

# %%
x = kh2po4["Raman Shift (cm-1)"]
y = kh2po4["Intensity"]
plt.figure(figsize=(25,10))
plt.plot(x,y)
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.xlim()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e8dcb45f4edd> in <module>
# ----> 1 x = kh2po4["Raman Shift (cm-1)"]
#       2 y = kh2po4["Intensity"]
#       3 plt.figure(figsize=(25,10))
#       4 plt.plot(x,y)
#       5 plt.xlabel('Raman Shift')
#
# NameError: name 'kh2po4' is not defined

# %%
x = diamond["Raman Shift (cm-1)"]
y = diamond["Intensity"]
plt.figure(figsize=(25,10))
plt.plot(x,y)
plt.xlabel('Raman Shift')
plt.ylabel('Intensity')
plt.xlim()
plt.show()
